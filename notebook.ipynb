# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Task 1

# %% [markdown]
# The given data contains **1500** rows and **8** columns. Firstly, the data needs to be validated according the the given criteria in the instructions. Looking at the columns one by one:
#
# - **product_id** is a unique identifier, hence, missing or duplicate values are not possible.
# - **category** column contained 25 missing values which were replaced with 'Unknown'. Other values were in the mentioned 6 types i.e. Housing, Food, Toys, Equipment, Medicine and Accessory.
# - **animal** contained no missing values and all data was of the 4 mentioned types namely : Cat, Dog, Bird, Fish.
# - **size** column had 3 types Small, Medium and Large but in a few places had inconsistent cases (eg. SMALL or small). Changed the case so that all three begin with a capital letter.
# - **price** column format was text originally so I transformed it to decimal number. It contained 150 unlisted data which were replaced with the overall median price (28.06) as mentioned. Also, I rounded off all values to two decimal places.
# -  **sales** column contained no missing values. Rounded off all values to two decimal places.
# -  **rating** contained 150 ratings with NA value. Replaced those with 0. Data type was text and was changed to whole number.
# -  **repeat_purchase** contained 0 or 1 with no missing values.

# %% [markdown]
# ## Task 2

# %% [markdown]
# The number of repeat purchases out of the given data is 906. From the following visualizations we can see that Equipment category has the most number of observations when plotted against sum of repeated purchases amounting to 221. We also see that the categories Medicine, Housing, Toys and Food have a comparable number of repeated purchases, whereas, Accessory has the least number out of the known categories.

# %% [markdown]
# ![Screenshot 2023-04-10 012449](Screenshot%202023-04-10%20012449.png)

# %% [markdown]
# ![Screenshot 2023-04-09 193620](Screenshot%202023-04-09%20193620.png)

# %% [markdown]
# ## Task 3

# %% [markdown]
# From the following visualization we can understand that sales values for most products lies between 878 and 1075. 437 products registered sales between 878 and 1075 followed by 338 products between range 681 and 878. Very few products have registered sales greater than 1468. There is a steady increase seen in the number of products as the sales value increases till 1075. Post that we see a steep drop in the number of products until it increases again.

# %% [markdown]
# ![image-2](image-2.png)

# %% [markdown]
# ## Task 4

# %% [markdown]
# Essentially, we need to combine the previous two pieces of information to analyze how repeat purchases impact sales. For the purpose of this visualization, I transformed repeat_purchase column to only include the products that are repeatedly bought i.e. '1' value. From the following line and column chart we notice that sum of sales by category does not follow the same trend as repeat purchases by category. Equipment products have the highest number of repeat purchases. Much higher than the number of repeat purchases of Toys. Yet still, the sum of sales of Toys is only lesser than the sum of sales of Equipment by about 25k. Whereas, repeat purchases for Medicines is higher than Toys. Still, the total sales of medicines are lower than Toys.

# %% [markdown]
# ![Screenshot 2023-04-10 002808](Screenshot%202023-04-10%20002808.png)

# %% [markdown]
# ![Screenshot 2023-04-10 004556](Screenshot%202023-04-10%20004556.png)

# %% [markdown]
# This is due to the fact that the average selling amount of Toys is the highest. Evidently, Equipment is the most popular category and people tend to spend more on Toys on average. Thus, to increase sales, PetMind needs to apply their strategy of repeated purchases on luxury products rather than everyday products like food and medicine.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
